# %%
# Configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
#importando os dados 

# importando os pacotes
df_pacotes = pd.read_csv('./pacotes_01_01__04_01.csv', delimiter=',',encoding='utf-16')

#importando os valores por localidade
df_valores_localidade = pd.read_csv('./valores_localidade.csv', delimiter=',', encoding='utf-16')

#Importando as planilhas dos agregados
df_agregados = pd.read_csv('./agregados_full.csv', delimiter=',', encoding='utf-16')

# %%
df_pacotes.head()
# Out:
#    Unnamed: 0     Numero_do_pedido Franqueado Base_de_entrega  \
# 0           0  888000348185085-000  NP CFB 01      CD ITB 001
# 1           1  888000363692615-000  NP CFB 01      CD ARR 001
# 2           2  888000365660866-000  NP LIN 01      CD CLN 001
# 3           3  888000366077634-000  NP DQC 01      CD NVF 001
# 4           4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                         Agregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# ...

# %%
df_pacotes[df_pacotes['CNPJ_CPF'].isna()]
# Out:
#        Unnamed: 0     Numero_do_pedido Franqueado Base_de_entrega  \
# 41533       41533  888500692375987-000  NP RIO 02      CD RIO 003
# 41558       41558  888500715087614-000  NP RIO 02      CD RIO 003
# 41560       41560  888500715665005-000  NP RIO 02      CD RIO 003
#
#                        Agregado                         Assinatura  \
# 41533  LUCIANO PEREIRA DA SILVA  Recebimento com assinatura normal
# 41558  LUCIANO PEREIRA DA SILVA  Recebimento com assinatura normal
# 41560  LUCIANO PEREIRA DA SILVA  Recebimento com assinatura normal
#
#        Valor_mercadoria  CEP_destino  \
# 41533             14.99     23570530
# 41558             10.90     20220180
# 41560             35.89     20950150
#
#                               Endereco_detalhado_destino          Cidade  \
# 41533  Travessa Francisco Belisário, 551, Casa 23 lot...  RIO DE JANEIRO
# 41558                               Rua Mont Alverne, 85  RIO DE JANEIRO
# ...

# %%
df_agregados[df_agregados['Agregado'] == 'LUCIANO PEREIRA DA SILVA']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Agregado, CPF, Placa, Base_vinculado, Tipo_veiculo, Marca_do_veiculo]
# Index: []

# %%
df_pacotes['CNPJ_CPF'].fillna('0000000000',inplace=True)

df_pacotes.isnull().sum()
# Out:
# Unnamed: 0                    0
# Numero_do_pedido              0
# Franqueado                    0
# Base_de_entrega               0
# Agregado                      0
# Assinatura                    0
# Valor_mercadoria              0
# CEP_destino                   0
# Endereco_detalhado_destino    0
# Cidade                        0
# Bairro                        0
# Destinatario                  0
# Data_da_entrega               0
# CNPJ_CPF                      0
# Peso_cobravel                 0
# dtype: int64

# %%
df_pacotes[df_pacotes['Agregado'] == 'LUCIANO PEREIRA DA SILVA']
# Out:
#        Unnamed: 0     Numero_do_pedido Franqueado Base_de_entrega  \
# 41533       41533  888500692375987-000  NP RIO 02      CD RIO 003
# 41558       41558  888500715087614-000  NP RIO 02      CD RIO 003
# 41560       41560  888500715665005-000  NP RIO 02      CD RIO 003
#
#                        Agregado                         Assinatura  \
# 41533  LUCIANO PEREIRA DA SILVA  Recebimento com assinatura normal
# 41558  LUCIANO PEREIRA DA SILVA  Recebimento com assinatura normal
# 41560  LUCIANO PEREIRA DA SILVA  Recebimento com assinatura normal
#
#        Valor_mercadoria  CEP_destino  \
# 41533             14.99     23570530
# 41558             10.90     20220180
# 41560             35.89     20950150
#
#                               Endereco_detalhado_destino          Cidade  \
# 41533  Travessa Francisco Belisário, 551, Casa 23 lot...  RIO DE JANEIRO
# 41558                               Rua Mont Alverne, 85  RIO DE JANEIRO
# ...

# %%
#filtrando por franqueado

df_np_rio_02 = df_pacotes[df_pacotes['Franqueado'] == 'NP RIO 02']

df_np_rio_02.head()
# Out:
#      Unnamed: 0     Numero_do_pedido Franqueado Base_de_entrega  \
# 24           24  888000372469935-000  NP RIO 02      CD RIO 006
# 53           53  888000375563743-000  NP RIO 02      CD RIO 006
# 86           86  888000378271234-000  NP RIO 02      CD RIO 006
# 109         109  888000379061468-000  NP RIO 02      CD RIO 001
# 159         159  888000380360369-000  NP RIO 02      CD RIO 006
#
#                                    Agregado  \
# 24   NATALIA CRISTINE ALVES DE ARAUJO SILVA
# 53   NATALIA CRISTINE ALVES DE ARAUJO SILVA
# 86   NATALIA CRISTINE ALVES DE ARAUJO SILVA
# 109                 TAMIRES MACHADO VICENTE
# 159  NATALIA CRISTINE ALVES DE ARAUJO SILVA
#
#                             Assinatura  Valor_mercadoria  CEP_destino  \
# 24   Recebimento com assinatura normal             16.09     23097280
# 53   Recebimento com assinatura normal             14.40     23097510
# 86   Recebimento com assinatura normal             79.99     23097240
# ...

# %%
df_np_rio_02.shape
# Out:
# (58986, 15)

# %%
df_np_rio_02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58986 entries, 24 to 114948
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  58986 non-null  int64
#  1   Numero_do_pedido            58986 non-null  object
#  2   Franqueado                  58986 non-null  object
#  3   Base_de_entrega             58986 non-null  object
#  4   Agregado                    58986 non-null  object
#  5   Assinatura                  58986 non-null  object
#  6   Valor_mercadoria            58986 non-null  float64
#  7   CEP_destino                 58986 non-null  int64
#  8   Endereco_detalhado_destino  58986 non-null  object
#  9   Cidade                      58986 non-null  object
#  10  Bairro                      58986 non-null  object
#  11  Destinatario                58986 non-null  object
#  12  Data_da_entrega             58986 non-null  object
# ...

# %%
df_np_rio_02['CNPJ_CPF'] = df_np_rio_02['CNPJ_CPF'].str.replace(r'\.0$', '')

df_np_rio_02.head()
# Out:
#      Unnamed: 0     Numero_do_pedido Franqueado Base_de_entrega  \
# 24           24  888000372469935-000  NP RIO 02      CD RIO 006
# 53           53  888000375563743-000  NP RIO 02      CD RIO 006
# 86           86  888000378271234-000  NP RIO 02      CD RIO 006
# 109         109  888000379061468-000  NP RIO 02      CD RIO 001
# 159         159  888000380360369-000  NP RIO 02      CD RIO 006
#
#                                    Agregado  \
# 24   NATALIA CRISTINE ALVES DE ARAUJO SILVA
# 53   NATALIA CRISTINE ALVES DE ARAUJO SILVA
# 86   NATALIA CRISTINE ALVES DE ARAUJO SILVA
# 109                 TAMIRES MACHADO VICENTE
# 159  NATALIA CRISTINE ALVES DE ARAUJO SILVA
#
#                             Assinatura  Valor_mercadoria  CEP_destino  \
# 24   Recebimento com assinatura normal             16.09     23097280
# 53   Recebimento com assinatura normal             14.40     23097510
# 86   Recebimento com assinatura normal             79.99     23097240
# ...
