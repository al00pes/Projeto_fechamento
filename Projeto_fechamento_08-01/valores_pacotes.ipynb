# %%
# Configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
#importando os dados 

# importando os pacotes
df_pacotes = pd.read_csv('./pacotes_01_01__04_01.csv', delimiter=',', encoding='utf-16')

#importando os valores por localidade
df_valores_localidade = pd.read_csv('./valores_localidade.csv', delimiter=',', encoding='utf-16')

#Importando as planilhas dos agregados
df_agregados = pd.read_csv('./agregados_full.csv', delimiter=',', encoding='utf-16')

# %%
#deletando a primeira coluna

df_agregados.drop('Unnamed: 0',axis=1 , inplace=True)

#Exibir o dataframe
df_agregados.head()
# Out:
#                     Agregado          CPF    Placa       Base_vinculado  \
# 0  ADEILTON JESUS DE SANTANA   1525260561  LOE9E90  REGIONAL SPONSOR RJ
# 1     LUCAS AGUIAR DE CASTRO   6282445760  KXV9G53               RIO 01
# 2  ERNANI NASCIMENTO DE LIMA  17165926747  RJV3B38  REGIONAL SPONSOR RJ
# 3    LUCIANO VAGNER DA COSTA  11466980621  Ahs6441               RIO 01
# 4     ALUIZIO CARLOS MIRANDA   7948591788  KQL1326               RIO 01
#
#   Tipo_veiculo     Marca_do_veiculo
# 0        CARRO  CITROEN JUMPER 320M
# 1        CARRO                 FIAT
# 2         MOTO               YAMAHA
# 3        CARRO                 fiat
# 4        CARRO                  Uno

# %%
#deletando a primeira coluna

df_pacotes.drop('Unnamed: 0', axis=1, inplace=True)

# Exibindo o dataframe

df_pacotes.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                         Agregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
df_pacotes['CNPJ_CPF'] = df_pacotes['CNPJ_CPF'].astype(str)

#Exibindo 

df_pacotes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Numero_do_pedido            114949 non-null  object
#  1   Franqueado                  114949 non-null  object
#  2   Base_de_entrega             114949 non-null  object
#  3   Agregado                    114949 non-null  object
#  4   Assinatura                  114949 non-null  object
#  5   Valor_mercadoria            114949 non-null  float64
#  6   CEP_destino                 114949 non-null  int64
#  7   Endereco_detalhado_destino  114949 non-null  object
#  8   Cidade                      114949 non-null  object
#  9   Bairro                      114949 non-null  object
#  10  Destinatario                114949 non-null  object
#  11  Data_da_entrega             114949 non-null  object
#  12  CNPJ_CPF                    114949 non-null  object
# ...

# %%
df_pacotes.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                         Agregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
#Neste exemplo, r'\.0$' é uma expressão regular que corresponde a ".0" no final da string. 
#O método str.replace é utilizado para substituir 
#todas as ocorrências desse padrão por uma string vazia.

df_pacotes['CNPJ_CPF'] = df_pacotes['CNPJ_CPF'].str.replace(r'\.0$', '')

#Exibindo o dataframe
df_pacotes.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                         Agregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
#modificando o nome da coluna para CPF

df_pacotes.rename(columns={'CNPJ_CPF':'CPF'},inplace=True)

#Exibindo o dataframe

df_pacotes.head(1)
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega               Agregado  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001  DAVID DA SILVA MACEDO
#
#                           Assinatura  Valor_mercadoria  CEP_destino  \
# 0  Recebimento com assinatura normal              74.0     24800240
#
#               Endereco_detalhado_destino    Cidade           Bairro  \
# 0  .Rua Promotor Ciro Olímpio da Mata 18  ITABORAÍ  JARDIM IMPERIAL
#
#                   Destinatario Data_da_entrega            CPF  Peso_cobravel
# 0  JAQUELINE CASSI  NASCIMENTO      2024-01-04  11636063756.0           0.57

# %%
#Neste exemplo, r'\.0$' é uma expressão regular que corresponde a ".0" no final da string. 
#O método str.replace é utilizado para substituir 
#todas as ocorrências desse padrão por uma string vazia.

df_pacotes['CPF'] =  df_pacotes['CPF'].replace(r'\.0$','')

#Exibindo o dataframe
df_pacotes.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                         Agregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
df_pacotes['CPF'] = df_pacotes['CPF'].astype(str)

# %%
df_pacotes.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                         Agregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
df_pacotes['CPF'] =  df_pacotes['CPF'].replace(r'\.0$','')

df_pacotes.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                         Agregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
#deletando a primeira coluna

df_valores_localidade.drop('Unnamed: 0', axis=1, inplace=True)

# Exibindo o dataframe

df_valores_localidade.head()
# Out:
#          Base       Cidade              Bairro  Valor_entrega Tipo_veiculo
# 0  CD NVI 001  NOVA IGUAÇU  BAIRRO INEXISTENTE            2.8        CARRO
# 1  CD NVI 001  NOVA IGUAÇU               KM 32            3.7        CARRO
# 2  CD NVI 001    QUEIMADOS  BAIRRO INEXISTENTE            2.8        CARRO
# 3  CD NVI 001     MESQUITA  BAIRRO INEXISTENTE            2.8        CARRO
# 4  CD NVI 001       JAPERI  BAIRRO INEXISTENTE            3.0        CARRO

# %%
#verificando os nulos

df_agregados.isnull().sum()
# Out:
# Agregado            0
# CPF                 0
# Placa               0
# Base_vinculado      7
# Tipo_veiculo        0
# Marca_do_veiculo    0
# dtype: int64

# %%
df_pacotes.isnull().sum()
# Out:
# Numero_do_pedido              0
# Franqueado                    0
# Base_de_entrega               0
# Agregado                      0
# Assinatura                    0
# Valor_mercadoria              0
# CEP_destino                   0
# Endereco_detalhado_destino    0
# Cidade                        0
# Bairro                        0
# Destinatario                  0
# Data_da_entrega               0
# CPF                           0
# Peso_cobravel                 0
# dtype: int64

# %%
df_pacotes.shape
# Out:
# (114949, 14)

# %%
df_valores_localidade.isnull().sum()
# Out:
# Base             0
# Cidade           0
# Bairro           0
# Valor_entrega    0
# Tipo_veiculo     0
# dtype: int64

# %% [markdown]
# A Primeira junção será entre o datafram pacotes e agregados.
# Assim será impossível identificar o tipo de veículo por agregado na entrega do pacotes
# e posteriormente unir com os valores dos pacotes

# %%
#exibindo as 
df_agregados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6393 entries, 0 to 6392
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Agregado          6393 non-null   object
#  1   CPF               6393 non-null   int64
#  2   Placa             6393 non-null   object
#  3   Base_vinculado    6386 non-null   object
#  4   Tipo_veiculo      6393 non-null   object
#  5   Marca_do_veiculo  6393 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 299.8+ KB

# %%
#Modificando o tipo da coluna CPF no dt_agregados

df_agregados['CPF'] = df_agregados['CPF'].astype(str)

#exibindo a informação
df_agregados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6393 entries, 0 to 6392
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Agregado          6393 non-null   object
#  1   CPF               6393 non-null   object
#  2   Placa             6393 non-null   object
#  3   Base_vinculado    6386 non-null   object
#  4   Tipo_veiculo      6393 non-null   object
#  5   Marca_do_veiculo  6393 non-null   object
# dtypes: object(6)
# memory usage: 299.8+ KB

# %%
df_agregados.head()
# Out:
#                     Agregado          CPF    Placa       Base_vinculado  \
# 0  ADEILTON JESUS DE SANTANA   1525260561  LOE9E90  REGIONAL SPONSOR RJ
# 1     LUCAS AGUIAR DE CASTRO   6282445760  KXV9G53               RIO 01
# 2  ERNANI NASCIMENTO DE LIMA  17165926747  RJV3B38  REGIONAL SPONSOR RJ
# 3    LUCIANO VAGNER DA COSTA  11466980621  Ahs6441               RIO 01
# 4     ALUIZIO CARLOS MIRANDA   7948591788  KQL1326               RIO 01
#
#   Tipo_veiculo     Marca_do_veiculo
# 0        CARRO  CITROEN JUMPER 320M
# 1        CARRO                 FIAT
# 2         MOTO               YAMAHA
# 3        CARRO                 fiat
# 4        CARRO                  Uno

# %%
df_pacotes['CPF'].astype(str).re
# Out:
# <bound method Series.round of 0         11636063756.0
# 1         11254511733.0
# 2         13084258724.0
# 3          5485985769.0
# 4          5485985769.0
#               ...
# 114944     2564379710.0
# 114945     9414257705.0
# 114946    14094457712.0
# 114947     9227271716.0
# 114948     9414257705.0
# Name: CPF, Length: 114949, dtype: object>

# %%
#junção 
pacotes_agregados = pd.merge(df_pacotes,df_agregados, on='CPF', how='left')

#Exibindo o dataframe

pacotes_agregados.shape
# Out:
# (114949, 19)

# %%
df_pacotes.shape
# Out:
# (114949, 14)

# %%
pacotes_agregados.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                       Agregado_x                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %% [markdown]
# agora irei fazer a junção do tipo de veículo por valor da entrega

# %%
#junção
df_pacotes_valores_agregados = pd.merge(pacotes_agregados,df_valores_localidade, on='Tipo_veiculo', how='left')

#Exibindo
df_pacotes_valores_agregados.shape
# Out:
# (114949, 23)

# %%
df_valores_localidade.head()
# Out:
#          Base       Cidade              Bairro  Valor_entrega Tipo_veiculo
# 0  CD NVI 001  NOVA IGUAÇU  BAIRRO INEXISTENTE            2.8        CARRO
# 1  CD NVI 001  NOVA IGUAÇU               KM 32            3.7        CARRO
# 2  CD NVI 001    QUEIMADOS  BAIRRO INEXISTENTE            2.8        CARRO
# 3  CD NVI 001     MESQUITA  BAIRRO INEXISTENTE            2.8        CARRO
# 4  CD NVI 001       JAPERI  BAIRRO INEXISTENTE            3.0        CARRO

# %%
pacotes_agregados.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                       Agregado_x                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
#excluído coluna

pacotes_agregados.drop('Agregado_y',axis=1,inplace=True)

pacotes_agregados.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                       Agregado_x                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
pacotes_agregados.rename(columns={'Agregado_x':'Aagregado'}, inplace=True)

pacotes_agregados.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
# 2  888000365660866-000  NP LIN 01      CD CLN 001
# 3  888000366077634-000  NP DQC 01      CD NVF 001
# 4  888000366077634-002  NP DQC 01      CD NVF 001
#
#                        Aagregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
# 2  CRISTIANO BERTOLACIO DA SILVA  Recebimento com assinatura normal
# 3        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
# 4        RODRIGO SCHOTT PINHEIRO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
# 2              2.40     29770000
# 3            125.20     28625630
# 4             49.47     28625630
#
# ...

# %%
pacotes_agregados.rename(columns={'Aagregado':'Agregado'}, inplace=True)

pacotes_agregados.head(2)
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000348185085-000  NP CFB 01      CD ITB 001
# 1  888000363692615-000  NP CFB 01      CD ARR 001
#
#                         Agregado                         Assinatura  \
# 0          DAVID DA SILVA MACEDO  Recebimento com assinatura normal
# 1  MARCOS VINICIUS SANTOS LEVINO  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             74.00     24800240
# 1             17.94     28993001
#
#                           Endereco_detalhado_destino     Cidade  \
# 0              .Rua Promotor Ciro Olímpio da Mata 18   ITABORAÍ
# 1  .Estrada do Engenho Grande, Proximo a adventis...  SAQUAREMA
#
#                     Bairro                 Destinatario Data_da_entrega  \
# 0          JARDIM IMPERIAL  JAQUELINE CASSI  NASCIMENTO      2024-01-04
# 1  ENGENHO GRANDE (BACAXA)             JULIA  MAGALHÃES      2024-01-04
#
#              CPF  Peso_cobravel Placa Base_vinculado Tipo_veiculo  \
# ...

# %%
pacotes_agregados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Numero_do_pedido            114949 non-null  object
#  1   Franqueado                  114949 non-null  object
#  2   Base_de_entrega             114949 non-null  object
#  3   Agregado                    114949 non-null  object
#  4   Assinatura                  114949 non-null  object
#  5   Valor_mercadoria            114949 non-null  float64
#  6   CEP_destino                 114949 non-null  int64
#  7   Endereco_detalhado_destino  114949 non-null  object
#  8   Cidade                      114949 non-null  object
#  9   Bairro                      114949 non-null  object
#  10  Destinatario                114949 non-null  object
#  11  Data_da_entrega             114949 non-null  object
#  12  CPF                         114949 non-null  object
# ...

# %%
df_valores_localidade.head(3)
# Out:
#          Base       Cidade              Bairro  Valor_entrega Tipo_veiculo
# 0  CD NVI 001  NOVA IGUAÇU  BAIRRO INEXISTENTE            2.8        CARRO
# 1  CD NVI 001  NOVA IGUAÇU               KM 32            3.7        CARRO
# 2  CD NVI 001    QUEIMADOS  BAIRRO INEXISTENTE            2.8        CARRO

# %%
df_valores_localidade.rename(columns={'Base':'Base_de_entrega'},inplace=True)

# %%
df_valores_localidade.head()
# Out:
#   Base_de_entrega       Cidade              Bairro  Valor_entrega Tipo_veiculo
# 0      CD NVI 001  NOVA IGUAÇU  BAIRRO INEXISTENTE            2.8        CARRO
# 1      CD NVI 001  NOVA IGUAÇU               KM 32            3.7        CARRO
# 2      CD NVI 001    QUEIMADOS  BAIRRO INEXISTENTE            2.8        CARRO
# 3      CD NVI 001     MESQUITA  BAIRRO INEXISTENTE            2.8        CARRO
# 4      CD NVI 001       JAPERI  BAIRRO INEXISTENTE            3.0        CARRO

# %%
df_valores_localidade.shape
# Out:
# (1194, 6)

# %%
df_valores_localidade[df_valores_localidade['Base'] == 'CD RIO 006']
# Out:
#      Unnamed: 0        Base          Cidade              Bairro  \
# 394          61  CD RIO 006  RIO DE JANEIRO  BAIRRO INEXISTENTE
# 395          62  CD RIO 006  RIO DE JANEIRO          SANTA CRUZ
# 396          63  CD RIO 006  RIO DE JANEIRO            SEPETIBA
# 397          64  CD RIO 006      SEROPÉDICA  BAIRRO INEXISTENTE
# 398          65  CD RIO 006         ITAGUAÍ  BAIRRO INEXISTENTE
# 399          66  CD RIO 006  RIO DE JANEIRO        CAMPO GRANDE
# 484         151  CD RIO 006  RIO DE JANEIRO  BAIRRO INEXISTENTE
# 485         152  CD RIO 006  RIO DE JANEIRO          SANTA CRUZ
# 486         153  CD RIO 006  RIO DE JANEIRO            SEPETIBA
# 487         154  CD RIO 006      SEROPÉDICA  BAIRRO INEXISTENTE
# 488         155  CD RIO 006         ITAGUAÍ  BAIRRO INEXISTENTE
# 489         156  CD RIO 006  RIO DE JANEIRO        CAMPO GRANDE
# 574         241  CD RIO 006  RIO DE JANEIRO  BAIRRO INEXISTENTE
# 575         242  CD RIO 006  RIO DE JANEIRO          SANTA CRUZ
# ...

# %%
df_valores_localidade['Base'].unique()
# Out:
# array(['CD NVI 001', 'CD SJT 001', 'CD DQC 002', 'CD DQC 001',
#        'CD AST 001', 'CD RIO 001', 'CD RIO 002', 'CD RIO 003',
#        'CD RIO 004', 'CD RIO 005', 'CD RIO 009', 'CD RIO 010',
#        'CD RIO 006', 'CD RIO 007', 'CD RIO 008', 'CD CFB 001',
#        'CD MAC 001', 'CD CPG 001', 'CD IPE 001', 'CD ARR 001',
#        'CD NVF 001', 'CD PTL 001', 'CD TRS 001', 'CD CRD 001',
#        'CD TRI 001', 'CD VTR 001', 'CD BPR 001', 'CD ADR 001',
#        'CD RSD 001'], dtype=object)

# %%
# importando o csv que contem os pacotes entregue com os dados dos agregados

pacotes_agregados = pd.read_csv('./pacotes_agregados.csv', encoding='utf-8')

pacotes_agregados.head()
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000372469935-000  NP RIO 02      CD RIO 006
# 1  888000375563743-000  NP RIO 02      CD RIO 006
# 2  888000378271234-000  NP RIO 02      CD RIO 006
# 3  888000379061468-000  NP RIO 02      CD RIO 001
# 4  888000380360369-000  NP RIO 02      CD RIO 006
#
#                                Agregado_x                         Assinatura  \
# 0  NATALIA CRISTINE ALVES DE ARAUJO SILVA  Recebimento com assinatura normal
# 1  NATALIA CRISTINE ALVES DE ARAUJO SILVA  Recebimento com assinatura normal
# 2  NATALIA CRISTINE ALVES DE ARAUJO SILVA  Recebimento com assinatura normal
# 3                 TAMIRES MACHADO VICENTE  Recebimento com assinatura normal
# 4  NATALIA CRISTINE ALVES DE ARAUJO SILVA  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             16.09     23097280
# 1             14.40     23097510
# 2             79.99     23097240
# 3             99.00     22720410
# ...

# %%
#transformando o atributo ['CPF']

pacotes_agregados['CPF'] = pacotes_agregados['CPF'].astype(str)

pacotes_agregados['CPF'] = pacotes_agregados['CPF'].str.replace(r'\.0$', '')

pacotes_agregados.head(3)
# Out:
#       Numero_do_pedido Franqueado Base_de_entrega  \
# 0  888000372469935-000  NP RIO 02      CD RIO 006
# 1  888000375563743-000  NP RIO 02      CD RIO 006
# 2  888000378271234-000  NP RIO 02      CD RIO 006
#
#                                Agregado_x                         Assinatura  \
# 0  NATALIA CRISTINE ALVES DE ARAUJO SILVA  Recebimento com assinatura normal
# 1  NATALIA CRISTINE ALVES DE ARAUJO SILVA  Recebimento com assinatura normal
# 2  NATALIA CRISTINE ALVES DE ARAUJO SILVA  Recebimento com assinatura normal
#
#    Valor_mercadoria  CEP_destino  \
# 0             16.09     23097280
# 1             14.40     23097510
# 2             79.99     23097240
#
#                           Endereco_detalhado_destino          Cidade  \
# 0  .Rua Quarenta e Sete(Nossa Senhora das Graças)...  RIO DE JANEIRO
# 1         .Rua Sessenta e Nove(Antiga) Qd 88 lote 08  RIO DE JANEIRO
# 2  .Rua Sessenta e Três(N S Graças) Qd 85 Lote 14...  RIO DE JANEIRO
#
# ...
